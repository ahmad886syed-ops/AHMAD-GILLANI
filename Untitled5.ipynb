# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad886syed-ops/AHMAD-GILLANI/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Alice'],
    'Age': [25, np.nan, 35, 25],
    'Salary': ['50000', '60000', np.nan, '50000']
})

# Remove duplicates
df = df.drop_duplicates()

# Fill missing Age values
df['Age'] = df['Age'].fillna(df['Age'].mean())

# Convert Salary to numeric
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')

# Fill missing Salary values
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())

print(df)
# Out:
#       Name   Age   Salary
# 0    Alice  25.0  50000.0
# 1      Bob  30.0  60000.0
# 2  Charlie  35.0  55000.0
